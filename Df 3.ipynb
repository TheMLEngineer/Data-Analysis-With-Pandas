# %%
import pandas as pd

# %%
bond = pd.read_csv('jamesbond.csv')

# %%
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index('Film',inplace = True)

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond = pd.read_csv('jamesbond.csv',index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc['Goldfinger']
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc['Casino Royale' : 'Goldfinger']
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# Casino Royale           145.3                3.3
# Casino Royale            85.0                NaN
# Diamonds Are Forever     34.7                5.8
# ...

# %%
bond = pd.read_csv('jamesbond.csv',index_col='Film')
bond.sort_index(inplace=True)

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc['Goldfinger',["Director", 'Box Office']]
# Out:
# Director      Guy Hamilton
# Box Office           820.4
# Name: Goldfinger, dtype: object

# %%
bond.iloc[14,2]
# Out:
# 'John Glen'

# %%
bond.ix['Dr. No']
# Out:
# C:\Users\kmuthu2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                              1962
# Actor                Karthikeyan Muthu
# Director                 Terence Young
# Box Office                       448.8
# Budget                               7
# Bond Actor Salary                  0.6
# Name: Dr. No, dtype: object

# %%
bond.ix['Dr. No',"Actor"] = "Karthikeyan Muthu"
# Out:
# C:\Users\kmuthu2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask = bond["Actor"] == "Sean Connery"

# %%
mask
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia with Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again               True
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
bond.ix[mask,"Actor"] = "Karthikeyan Muthu"
# Out:
# C:\Users\kmuthu2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond
# Out:
#                                  Year              Actor            Director  \
# Film
# A View to a Kill                 1985        Roger Moore           John Glen
# Casino Royale                    2006       Daniel Craig     Martin Campbell
# Casino Royale                    1967        David Niven          Ken Hughes
# Diamonds Are Forever             1971  Karthikeyan Muthu        Guy Hamilton
# Die Another Day                  2002     Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Karthikeyan Muthu       Terence Young
# For Your Eyes Only               1981        Roger Moore           John Glen
# From Russia with Love            1963  Karthikeyan Muthu       Terence Young
# GoldenEye                        1995     Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Karthikeyan Muthu        Guy Hamilton
# Licence to Kill                  1989     Timothy Dalton           John Glen
# ...

# %%
bond.to_csv('KarthikeyanMuthu.csv',sep=',')

# %%
km = pd.read_csv('KarthikeyanMuthu.csv')

# %%
km
# Out:
#                                Film  Year              Actor  \
# 0                  A View to a Kill  1985        Roger Moore
# 1                     Casino Royale  2006       Daniel Craig
# 2                     Casino Royale  1967        David Niven
# 3              Diamonds Are Forever  1971  Karthikeyan Muthu
# 4                   Die Another Day  2002     Pierce Brosnan
# 5                            Dr. No  1962  Karthikeyan Muthu
# 6                For Your Eyes Only  1981        Roger Moore
# 7             From Russia with Love  1963  Karthikeyan Muthu
# 8                         GoldenEye  1995     Pierce Brosnan
# 9                        Goldfinger  1964  Karthikeyan Muthu
# 10                  Licence to Kill  1989     Timothy Dalton
# 11                 Live and Let Die  1973        Roger Moore
# 12                        Moonraker  1979        Roger Moore
# 13            Never Say Never Again  1983  Karthikeyan Muthu
# ...

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.drop('A View to a Kill')
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.drop("Box Office",axis = 1)
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
a = bond.pop('Box Office')

# %%
a
# Out:
# Film
# A View to a Kill                   275.2
# Casino Royale                      581.5
# Casino Royale                      315.0
# Diamonds Are Forever               442.5
# Die Another Day                    465.4
# Dr. No                             448.8
# For Your Eyes Only                 449.4
# From Russia with Love              543.8
# GoldenEye                          518.5
# Goldfinger                         820.4
# Licence to Kill                    250.9
# Live and Let Die                   460.3
# Moonraker                          535.0
# Never Say Never Again              380.0
# Octopussy                          373.8
# On Her Majesty's Secret Service    291.5
# Quantum of Solace                  514.2
# Skyfall                            943.5
# Spectre                            726.7
# The Living Daylights               313.5
# The Man with the Golden Gun        334.0
# The Spy Who Loved Me               533.0
# The World Is Not Enough            439.5
# ...

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
del bond['Director']

# %%
bond
# Out:
#                                  Year           Actor  Budget  \
# Film
# A View to a Kill                 1985     Roger Moore    54.5
# Casino Royale                    2006    Daniel Craig   145.3
# Casino Royale                    1967     David Niven    85.0
# Diamonds Are Forever             1971    Sean Connery    34.7
# Die Another Day                  2002  Pierce Brosnan   154.2
# Dr. No                           1962    Sean Connery     7.0
# For Your Eyes Only               1981     Roger Moore    60.2
# From Russia with Love            1963    Sean Connery    12.6
# GoldenEye                        1995  Pierce Brosnan    76.9
# Goldfinger                       1964    Sean Connery    18.6
# Licence to Kill                  1989  Timothy Dalton    56.7
# Live and Let Die                 1973     Roger Moore    30.8
# Moonraker                        1979     Roger Moore    91.5
# Never Say Never Again            1983    Sean Connery    86.0
# ...

# %% [markdown]
# ## Create random sample

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sample(n = 5)
# Out:
#                       Year         Actor       Director  Box Office  Budget  \
# Film
# Moonraker             1979   Roger Moore  Lewis Gilbert       535.0    91.5
# The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0    45.1
# Skyfall               2012  Daniel Craig     Sam Mendes       943.5   170.2
# Casino Royale         1967   David Niven     Ken Hughes       315.0    85.0
# For Your Eyes Only    1981   Roger Moore      John Glen       449.4    60.2
#
#                       Bond Actor Salary
# Film
# Moonraker                           NaN
# The Spy Who Loved Me                NaN
# Skyfall                            14.5
# Casino Royale                       NaN
# For Your Eyes Only                  NaN

# %%
bond.sample(frac = 0.45)
# Out:
#                          Year           Actor         Director  Box Office  \
# Film
# Diamonds Are Forever     1971    Sean Connery     Guy Hamilton       442.5
# Licence to Kill          1989  Timothy Dalton        John Glen       250.9
# GoldenEye                1995  Pierce Brosnan  Martin Campbell       518.5
# For Your Eyes Only       1981     Roger Moore        John Glen       449.4
# The World Is Not Enough  1999  Pierce Brosnan    Michael Apted       439.5
# The Living Daylights     1987  Timothy Dalton        John Glen       313.5
# A View to a Kill         1985     Roger Moore        John Glen       275.2
# From Russia with Love    1963    Sean Connery    Terence Young       543.8
# Dr. No                   1962    Sean Connery    Terence Young       448.8
# Skyfall                  2012    Daniel Craig       Sam Mendes       943.5
# Casino Royale            1967     David Niven       Ken Hughes       315.0
# ...

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sort_values("Box Office", inplace=True,ascending = False)

# %%
bond.head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3, columns='Box Office')
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3,'Budget')
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond.nlargest(6,'Bond Actor Salary')
# Out:
#                          Year           Actor            Director  Box Office  \
# Film
# Die Another Day          2002  Pierce Brosnan        Lee Tamahori       465.4
# Skyfall                  2012    Daniel Craig          Sam Mendes       943.5
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted       439.5
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode       463.2
# A View to a Kill         1985     Roger Moore           John Glen       275.2
# Quantum of Solace        2008    Daniel Craig        Marc Forster       514.2
#
#                          Budget  Bond Actor Salary
# Film
# Die Another Day           154.2               17.9
# Skyfall                   170.2               14.5
# The World Is Not Enough   158.3               13.5
# Tomorrow Never Dies       133.9               10.0
# A View to a Kill           54.5                9.1
# Quantum of Solace         181.4                8.1

# %%
mask = bond["Actor"] == "Sean Connery"

# %%
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond Actor Salary
# Film
# Thunderball                          4.7
# Goldfinger                           3.2
# From Russia with Love                1.6
# You Only Live Twice                  4.4
# Dr. No                               0.6
# Diamonds Are Forever                 5.8
# ...

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# Skyfall                             NaN           NaN             NaN
# Thunderball                      1965.0  Sean Connery   Terence Young
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Spectre                             NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# Moonraker                           NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# GoldenEye                           NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
# Quantum of Solace                   NaN           NaN             NaN
# Die Another Day                     NaN           NaN             NaN
# ...

# %%
bond.columns = [column_name.replace(" ","_") for column_name in bond.columns]

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Thunderball                      1965    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Spectre                          2015    Daniel Craig          Sam Mendes
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# From Russia with Love            1963    Sean Connery       Terence Young
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# ...

# %%
bond.query('Director == "Sam Mendes"')
# Out:
#          Year         Actor    Director  Box_Office  Budget  Bond_Actor_Salary
# Film
# Skyfall  2012  Daniel Craig  Sam Mendes       943.5   170.2               14.5
# Spectre  2015  Daniel Craig  Sam Mendes       726.7   206.3                NaN

# %%
bond.query('Director == "Sam Mendes" and Actor == "Daniel Craig"')
# Out:
#          Year         Actor    Director  Box_Office  Budget  Bond_Actor_Salary
# Film
# Skyfall  2012  Daniel Craig  Sam Mendes       943.5   170.2               14.5
# Spectre  2015  Daniel Craig  Sam Mendes       726.7   206.3                NaN

# %%
bond.query('Director == "Sam Mendes" or Actor == "Daniel Craig"')
# Out:
#                    Year         Actor         Director  Box_Office  Budget  \
# Film
# Skyfall            2012  Daniel Craig       Sam Mendes       943.5   170.2
# Spectre            2015  Daniel Craig       Sam Mendes       726.7   206.3
# Casino Royale      2006  Daniel Craig  Martin Campbell       581.5   145.3
# Quantum of Solace  2008  Daniel Craig     Marc Forster       514.2   181.4
#
#                    Bond_Actor_Salary
# Film
# Skyfall                         14.5
# Spectre                          NaN
# Casino Royale                    3.3
# Quantum of Solace                8.1

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def to_million(num):
    return str(num) + "Millions"

# %%
bond["Box Office"] = bond["Box Office"].apply(to_million)

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director     Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen  275.2Millions    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell  581.5Millions   145.3
# Casino Royale     1967   David Niven       Ken Hughes  315.0Millions    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    actor = row[1]
    if actor == "Daniel Craig":
        return "Best Movie"
    else:
        return "Good"
    
bond.apply(good_movie,axis=1)
# Out:
# Film
# A View to a Kill                         Good
# Casino Royale                      Best Movie
# Casino Royale                            Good
# Diamonds Are Forever                     Good
# Die Another Day                          Good
# Dr. No                                   Good
# For Your Eyes Only                       Good
# From Russia with Love                    Good
# GoldenEye                                Good
# Goldfinger                               Good
# Licence to Kill                          Good
# Live and Let Die                         Good
# Moonraker                                Good
# Never Say Never Again                    Good
# Octopussy                                Good
# On Her Majesty's Secret Service          Good
# Quantum of Solace                  Best Movie
# Skyfall                            Best Movie
# Spectre                            Best Movie
# The Living Daylights                     Good
# ...

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
abc = bond['Director'].copy()

# %%
abc
# Out:
# Film
# A View to a Kill                            John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...
