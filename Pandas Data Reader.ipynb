# %%
import pandas as pd
import datetime as dt

# %%
from pandas_datareader import data
from pandas.tseries.offsets import *

# %%
company = "MSFT" # Stock market symbol of microsoft
start = '2010-1-1'
end = '2019-2-13'

stocks = data.DataReader(name=company,data_source="yahoo",start=start,end=end)
stocks
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2009-12-31   30.990000   30.480000   30.980000   30.480000   31929700.0
# 2010-01-04   31.100000   30.590000   30.620001   30.950001   38409100.0
# 2010-01-05   31.100000   30.639999   30.850000   30.959999   49749600.0
# 2010-01-06   31.080000   30.520000   30.879999   30.770000   58182400.0
# 2010-01-07   30.700001   30.190001   30.629999   30.450001   50559700.0
# 2010-01-08   30.879999   30.240000   30.280001   30.660000   51197400.0
# 2010-01-11   30.760000   30.120001   30.709999   30.270000   68754700.0
# 2010-01-12   30.400000   29.910000   30.150000   30.070000   65912100.0
# 2010-01-13   30.520000   30.010000   30.260000   30.350000   51863500.0
# 2010-01-14   31.100000   30.260000   30.309999   30.959999   63228100.0
# 2010-01-15   31.240000   30.709999   31.080000   30.860001   79913200.0
# 2010-01-19   31.240000   30.680000   30.750000   31.100000   46575700.0
# ...

# %%
stocks.values
# Out:
# array([[3.09899998e+01, 3.04799995e+01, 3.09799995e+01, 3.04799995e+01,
#         3.19297000e+07, 2.43455143e+01],
#        [3.11000004e+01, 3.05900002e+01, 3.06200008e+01, 3.09500008e+01,
#         3.84091000e+07, 2.47209282e+01],
#        [3.11000004e+01, 3.06399994e+01, 3.08500004e+01, 3.09599991e+01,
#         4.97496000e+07, 2.47289143e+01],
#        ...,
#        [1.06580002e+02, 1.04970001e+02, 1.06199997e+02, 1.05250000e+02,
#         1.89141000e+07, 1.05250000e+02],
#        [1.07139999e+02, 1.05480003e+02, 1.06139999e+02, 1.06889999e+02,
#         2.50213000e+07, 1.06889999e+02],
#        [1.07779999e+02, 1.06950203e+02, 1.07500000e+02, 1.07220001e+02,
#         6.00415800e+06, 1.07220001e+02]])

# %%
stocks.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
stocks.index
# Out:
# DatetimeIndex(['2009-12-31', '2010-01-04', '2010-01-05', '2010-01-06',
#                '2010-01-07', '2010-01-08', '2010-01-11', '2010-01-12',
#                '2010-01-13', '2010-01-14',
#                ...
#                '2019-01-31', '2019-02-01', '2019-02-04', '2019-02-05',
#                '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-11',
#                '2019-02-12', '2019-02-13'],
#               dtype='datetime64[ns]', name='Date', length=2295, freq=None)

# %%
stocks.index[0]
# Out:
# Timestamp('2009-12-31 00:00:00')

# %%
stocks.axes
# Out:
# [DatetimeIndex(['2009-12-31', '2010-01-04', '2010-01-05', '2010-01-06',
#                 '2010-01-07', '2010-01-08', '2010-01-11', '2010-01-12',
#                 '2010-01-13', '2010-01-14',
#                 ...
#                 '2019-01-31', '2019-02-01', '2019-02-04', '2019-02-05',
#                 '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-11',
#                 '2019-02-12', '2019-02-13'],
#                dtype='datetime64[ns]', name='Date', length=2295, freq=None),
#  Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')]

# %% [markdown]
# ## Selecting from a dataframe with a DateTimeIndex

# %%
stocks = data.DataReader(name=company,data_source="yahoo",start=start,end=end)
stocks.head(3)
# Out:
#              High        Low       Open      Close      Volume  Adj Close
# Date
# 2009-12-31  30.99  30.480000  30.980000  30.480000  31929700.0  24.345514
# 2010-01-04  31.10  30.590000  30.620001  30.950001  38409100.0  24.720928
# 2010-01-05  31.10  30.639999  30.850000  30.959999  49749600.0  24.728914

# %%
stocks.loc["2014-3-3"]
# Out:
# High         3.813000e+01
# Low          3.749000e+01
# Open         3.792000e+01
# Close        3.778000e+01
# Volume       2.971750e+07
# Adj Close    3.375268e+01
# Name: 2014-03-03 00:00:00, dtype: float64

# %%
stocks.loc["2016-1-1"]

# Gives error because that day is not business day so stock market was not open on that day
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine._date_check_type()
#
# ...

# %%
stocks.loc['2011-1-1':'2012-1-1']

# %%
birthdays = pd.date_range(start='1997-05-16',end='2018-12-31',freq=pd.DateOffset(years = 1))
# To get all my bdays betwwen 1997 and 2018

# %%
mask = stocks.index.isin(birthdays)

# %%
stocks[mask]

# %% [markdown]
# ## Timestamp object attributes

# %%
stocks = data.DataReader(name=company,data_source="yahoo",start=start,end=end)
stocks.head(3)

# %%
someday = stocks.index[500]
someday

# %%
someday.day

# %%
someday.month

# %%
someday.year

# %%
someday.hour

# %%
someday.weekday_name

# %%
stocks.insert(0,"Day of week",stocks.index.weekday_name)

# %%
stocks.head()

# %%
stocks.insert(1,"Start of month",stocks.index.is_month_start)

# %%
stocks

# %%
stocks[stocks["Start of month"]]
#Gives stock value in every month start

# %% [markdown]
# ## .truncate() method

# %%
stocks = data.DataReader(name=company,data_source="yahoo",start=start,end=end)
stocks.head(3)

# %%
stocks.truncate(before="2011-2-5",after="2011-2-28")

# %% [markdown]
# ## pd.DateOffset object

# %%
stocks = data.DataReader(name="GOOG",data_source="yahoo",start=dt.date(2000,1,1),end=dt.datetime.now())
stocks.head(3)

# %%
stocks.index

# %%
stocks.index + pd.DateOffset(days=5)

# %%
stocks.index + pd.DateOffset(weeks=2)

# %%
stocks.index - pd.DateOffset(weeks=2)

# %%
stocks.index - pd.DateOffset(years=1,month=3,days=10)

# %%
stocks = data.DataReader(name="GOOG",data_source="yahoo",start=dt.date(2000,1,1),end=dt.datetime.now())
stocks.head(3)

# %%
stocks.index + MonthEnd()
#Month end works because we already imported
#from pandas.tseries.offsets import *
# Out:
# DatetimeIndex(['2010-01-31', '2010-01-31', '2010-01-31', '2010-01-31',
#                '2010-01-31', '2010-01-31', '2010-01-31', '2010-01-31',
#                '2010-01-31', '2010-01-31',
#                ...
#                '2019-02-28', '2019-02-28', '2019-02-28', '2019-02-28',
#                '2019-02-28', '2019-02-28', '2019-02-28', '2019-02-28',
#                '2019-02-28', '2019-02-28'],
#               dtype='datetime64[ns]', name='Date', length=2295, freq=None)

# %%
stocks.index + MonthBegin()
# Out:
# DatetimeIndex(['2010-01-01', '2010-02-01', '2010-02-01', '2010-02-01',
#                '2010-02-01', '2010-02-01', '2010-02-01', '2010-02-01',
#                '2010-02-01', '2010-02-01',
#                ...
#                '2019-02-01', '2019-03-01', '2019-03-01', '2019-03-01',
#                '2019-03-01', '2019-03-01', '2019-03-01', '2019-03-01',
#                '2019-03-01', '2019-03-01'],
#               dtype='datetime64[ns]', name='Date', length=2295, freq=None)

# %%
stocks.index + BMonthEnd()
# Out:
# DatetimeIndex(['2010-01-29', '2010-01-29', '2010-01-29', '2010-01-29',
#                '2010-01-29', '2010-01-29', '2010-01-29', '2010-01-29',
#                '2010-01-29', '2010-01-29',
#                ...
#                '2019-02-28', '2019-02-28', '2019-02-28', '2019-02-28',
#                '2019-02-28', '2019-02-28', '2019-02-28', '2019-02-28',
#                '2019-02-28', '2019-02-28'],
#               dtype='datetime64[ns]', name='Date', length=2295, freq=None)

# %%
stocks.index + QuarterEnd()
# Out:
# DatetimeIndex(['2010-03-31', '2010-03-31', '2010-03-31', '2010-03-31',
#                '2010-03-31', '2010-03-31', '2010-03-31', '2010-03-31',
#                '2010-03-31', '2010-03-31',
#                ...
#                '2019-03-31', '2019-03-31', '2019-03-31', '2019-03-31',
#                '2019-03-31', '2019-03-31', '2019-03-31', '2019-03-31',
#                '2019-03-31', '2019-03-31'],
#               dtype='datetime64[ns]', name='Date', length=2295, freq=None)

# %%
stocks.index - QuarterEnd()
# Out:
# DatetimeIndex(['2009-09-30', '2009-12-31', '2009-12-31', '2009-12-31',
#                '2009-12-31', '2009-12-31', '2009-12-31', '2009-12-31',
#                '2009-12-31', '2009-12-31',
#                ...
#                '2018-12-31', '2018-12-31', '2018-12-31', '2018-12-31',
#                '2018-12-31', '2018-12-31', '2018-12-31', '2018-12-31',
#                '2018-12-31', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=2295, freq=None)

# %%
stocks.index + YearEnd()
# Out:
# DatetimeIndex(['2010-12-31', '2010-12-31', '2010-12-31', '2010-12-31',
#                '2010-12-31', '2010-12-31', '2010-12-31', '2010-12-31',
#                '2010-12-31', '2010-12-31',
#                ...
#                '2019-12-31', '2019-12-31', '2019-12-31', '2019-12-31',
#                '2019-12-31', '2019-12-31', '2019-12-31', '2019-12-31',
#                '2019-12-31', '2019-12-31'],
#               dtype='datetime64[ns]', name='Date', length=2295, freq=None)

# %% [markdown]
# ## The timeDelta object

# %%
timeA = pd.Timestamp('2016-3-31')
timeB = pd.Timestamp('2016-3-20')

# %%
timeA - timeB
# Out:
# Timedelta('11 days 00:00:00')

# %%
type(timeA - timeB)
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
type(timeA)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
timeB - timeA
# Out:
# Timedelta('-11 days +00:00:00')

# %%
pd.Timedelta( weeks=5,days = 3, minutes =5,hours = 5)
# Out:
# Timedelta('38 days 05:05:00')

# %%
pd.Timedelta("14 days 6 hours 12 minutes")
# weeks dont work if given in string
# Out:
# Timedelta('14 days 06:12:00')

# %% [markdown]
# ## timeDelta in dataset

# %%
shipping = pd.read_csv('ecommerce.csv',index_col = "ID",parse_dates = ["order_date","delivery_date"])

# %%
shipping.head(3)
# Out:
#    order_date delivery_date
# ID
# 1  1998-05-24    1999-02-05
# 2  1992-04-22    1998-03-06
# 4  1991-02-10    1992-08-26

# %%
shipping['delivery_time'] = shipping["delivery_date"] - shipping['order_date']

# %%
shipping.head(3)
# Out:
#    order_date delivery_date delivery_time
# ID
# 1  1998-05-24    1999-02-05      257 days
# 2  1992-04-22    1998-03-06     2144 days
# 4  1991-02-10    1992-08-26      563 days

# %%
shipping['twice_as_long'] = shipping['delivery_date'] + shipping['delivery_time']

# %%
shipping.head(3)
# Out:
#    order_date delivery_date delivery_time twice_as_long
# ID
# 1  1998-05-24    1999-02-05      257 days    1999-10-20
# 2  1992-04-22    1998-03-06     2144 days    2004-01-18
# 4  1991-02-10    1992-08-26      563 days    1994-03-12

# %%
shipping.dtypes
# Out:
# order_date        datetime64[ns]
# delivery_date     datetime64[ns]
# delivery_time    timedelta64[ns]
# twice_as_long     datetime64[ns]
# dtype: object

# %%
mask = shipping['delivery_time'] > '365 days'

# %%
shipping[mask]
# Out:
#     order_date delivery_date delivery_time twice_as_long
# ID
# 2   1992-04-22    1998-03-06     2144 days    2004-01-18
# 4   1991-02-10    1992-08-26      563 days    1994-03-12
# 5   1992-07-21    1997-11-20     1948 days    2003-03-22
# 7   1993-09-02    1998-06-10     1742 days    2003-03-18
# 9   1990-01-25    1994-10-02     1711 days    1999-06-09
# 10  1992-02-23    1998-12-30     2502 days    2005-11-05
# 11  1996-07-12    1997-07-14      367 days    1998-07-16
# 18  1995-06-18    1997-10-13      848 days    2000-02-08
# 20  1992-10-17    1998-10-06     2180 days    2004-09-24
# 23  1992-05-30    1999-08-15     2633 days    2006-10-30
# 26  1996-04-11    1998-05-04      753 days    2000-05-26
# 32  1990-01-20    1998-07-24     3107 days    2007-01-25
# 33  1994-09-21    1996-10-12      752 days    1998-11-03
# 35  1993-09-10    1996-04-28      961 days    1998-12-15
# 36  1990-05-15    1994-02-14     1371 days    1997-11-16
# ...

# %%
shipping['delivery_time'].max()
# Out:
# Timedelta('3583 days 00:00:00')

# %%
shipping['delivery_time'].min()
# Out:
# Timedelta('8 days 00:00:00')
